# %%
# %matplotlib inline

import datacube
import xarray as xr
import pandas as pd
import numpy as np
import odc
import matplotlib.pyplot as plt
from eo_tides.eo import tag_tides

from dea_tools.datahandling import load_ard, mostcommon_crs
from dea_tools.plotting import rgb, display_map
from dea_tools.bandindices import calculate_indices
from dea_tools.spatial import subpixel_contours
from dea_tools.dask import create_local_dask_cluster

# # Create local dask cluster to improve data load time
client = create_local_dask_cluster(return_client=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 import matplotlib.pyplot as plt
#       9 from eo_tides.eo import tag_tides
# ---> 11 from dea_tools.datahandling import load_ard, mostcommon_crs
#      12 from dea_tools.plotting import rgb, display_map
#      13 from dea_tools.bandindices import calculate_indices
#
# File /srv/conda/envs/notebook/lib/python3.12/site-packages/dea_tools/datahandling.py:32
#      29 from collections import Counter
#      31 import numpy as np
# ---> 32 import odc.algo
#      33 import odc.geo.xr
#      34 import pandas as pd
#
# ModuleNotFoundError: No module named 'odc.algo'

# %%
from eo_tides import list_models
list_models("~/data/coastlines/tide_models/")
# Out:
# ────────────────────────────────────────────────────────────────────────────────
#  󠀠🌊  | Model                | Expected path
# ────────────────────────────────────────────────────────────────────────────────
#  ❌  │ AODTM-5              │ /home/jovyan/data/coastlines/tide_models/aodtm5_tmd
#  ❌  │ AOTIM-5              │ /home/jovyan/data/coastlines/tide_models/aotim5_tmd
#  ❌  │ AOTIM-5-2018         │ /home/jovyan/data/coastlines/tide_models/Arc5km2018
#  ❌  │ Arc2kmTM             │ /home/jovyan/data/coastlines/tide_models/Arc2kmTM
#  ❌  │ CATS0201             │ /home/jovyan/data/coastlines/tide_models/cats0201_tmd
#  ❌  │ CATS2008             │ /home/jovyan/data/coastlines/tide_models/CATS2008
#  ❌  │ CATS2008-v2023       │ /home/jovyan/data/coastlines/tide_models/CATS2008_v2023
#  ❌  │ CATS2008_load        │ /home/jovyan/data/coastlines/tide_models/CATS2008a_SPOTL_Load
#  ❌  │ DTU23                │ /home/jovyan/data/coastlines/tide_models/DTU23_OceanTide/DTU23
#  ✅  │ EOT20                │ /home/jovyan/data/coastlines/tide_models/EOT20/ocean_tides
#  ✅  │ EOT20_load           │ /home/jovyan/data/coastlines/tide_models/EOT20/load_tides
#  ❌  │ FES2012              │ /home/jovyan/data/coastlines/tide_models/fes2012/data
#  ✅  │ FES2014              │ /home/jovyan/data/coastlines/tide_models/fes2014/ocean_tide
#  ✅  │ FES2014_extrapolated │ /home/jovyan/data/coastlines/tide_models/fes2014/ocean_tide_extrapolated
#  ✅  │ FES2014_load         │ /home/jovyan/data/coastlines/tide_models/fes2014/load_tide
#  ✅  │ FES2022              │ /home/jovyan/data/coastlines/tide_models/fes2022b/ocean_tide_20241025
#  ✅  │ FES2022_extrapolated │ /home/jovyan/data/coastlines/tide_models/fes2022b/ocean_tide_extrapolated
#  ✅  │ FES2022_load         │ /home/jovyan/data/coastlines/tide_models/fes2022b/load_tide
#  ❌  │ GOT4.10              │ /home/jovyan/data/coastlines/tide_models/GOT4.10c/grids_oceantide
#  ❌  │ GOT4.10_load         │ /home/jovyan/data/coastlines/tide_models/GOT4.10c/grids_loadtide
#  ❌  │ GOT4.7               │ /home/jovyan/data/coastlines/tide_models/GOT4.7/grids_oceantide
#  ❌  │ GOT4.7_load          │ /home/jovyan/data/coastlines/tide_models/GOT4.7/grids_loadtide
#  ❌  │ GOT4.8               │ /home/jovyan/data/coastlines/tide_models/got4.8/grids_oceantide
#  ❌  │ GOT4.8_load          │ /home/jovyan/data/coastlines/tide_models/got4.8/grids_loadtide
#  ✅  │ GOT5.5               │ /home/jovyan/data/coastlines/tide_models/GOT5.5/ocean_tides
#  ❌  │ GOT5.5D              │ /home/jovyan/data/coastlines/tide_models/GOT5.5/ocean_tides
#  ❌  │ GOT5.5D_extrapolated │ /home/jovyan/data/coastlines/tide_models/GOT5.5/extrapolated
#  ✅  │ GOT5.5_extrapolated  │ /home/jovyan/data/coastlines/tide_models/GOT5.5/extrapolated
#  ✅  │ GOT5.5_load          │ /home/jovyan/data/coastlines/tide_models/GOT5.5/load_tides
#  ✅  │ GOT5.6               │ /home/jovyan/data/coastlines/tide_models/GOT5.6/ocean_tides
#  ❌  │ GOT5.6_extrapolated  │ /home/jovyan/data/coastlines/tide_models/GOT5.6/extrapolated
#  ❌  │ Gr1km-v2             │ /home/jovyan/data/coastlines/tide_models/greenlandTMD_v2
#  ❌  │ Gr1kmTM              │ /home/jovyan/data/coastlines/tide_models/Gr1kmTM
#  ❌  │ HAMTIDE11            │ /home/jovyan/data/coastlines/tide_models/hamtide
#  ✅  │ INATIDES             │ /home/jovyan/data/coastlines/tide_models/INATIDES
#  ❌  │ RE14                 │ /home/jovyan/data/coastlines/tide_models/RE14_LongPeriodTides_rel/oceantides
#  ❌  │ TPXO10-atlas-v2      │ /home/jovyan/data/coastlines/tide_models/TPXO10_atlas_v2
#  ✅  │ TPXO10-atlas-v2-nc   │ /home/jovyan/data/coastlines/tide_models/TPXO10_atlas_v2
#  ❌  │ TPXO7.2              │ /home/jovyan/data/coastlines/tide_models/TPXO7.2_tmd
#  ❌  │ TPXO7.2_load         │ /home/jovyan/data/coastlines/tide_models/TPXO7.2_load
#  ❌  │ TPXO8-atlas          │ /home/jovyan/data/coastlines/tide_models/tpxo8_atlas
#  ❌  │ TPXO8-atlas-nc       │ /home/jovyan/data/coastlines/tide_models/TPXO8_atlas_v1
#  ❌  │ TPXO9-atlas          │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas
#  ❌  │ TPXO9-atlas-nc       │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas
#  ❌  │ TPXO9-atlas-v2       │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v2
#  ❌  │ TPXO9-atlas-v2-nc    │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v2
#  ❌  │ TPXO9-atlas-v3       │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v3
#  ❌  │ TPXO9-atlas-v3-nc    │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v3
#  ❌  │ TPXO9-atlas-v4       │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v4
#  ❌  │ TPXO9-atlas-v4-nc    │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v4
#  ❌  │ TPXO9-atlas-v5       │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v5
#  ✅  │ TPXO9-atlas-v5-nc    │ /home/jovyan/data/coastlines/tide_models/TPXO9_atlas_v5
#  ❌  │ TPXO9.1              │ /home/jovyan/data/coastlines/tide_models/TPXO9.1/DATA
# ────────────────────────────────────────────────────────────────────────────────
#
# Summary:
# Available models: 15/53
# (['EOT20',
#   'EOT20_load',
#   'FES2014',
#   'FES2014_extrapolated',
#   'FES2014_load',
#   'FES2022',
#   'FES2022_extrapolated',
#   'FES2022_load',
#   'GOT5.5',
#   'GOT5.5_extrapolated',
#   'GOT5.5_load',
#   'GOT5.6',
#   'INATIDES',
#   'TPXO10-atlas-v2-nc',
#   'TPXO9-atlas-v5-nc'],
#  ['AODTM-5',
#   'AOTIM-5',
#   'AOTIM-5-2018',
#   'Arc2kmTM',
#   'CATS0201',
#   'CATS2008',
#   'CATS2008-v2023',
#   'CATS2008_load',
#   'DTU23',
#   'EOT20',
#   'EOT20_load',
#   'FES2012',
#   'FES2014',
#   'FES2014_extrapolated',
#   'FES2014_load',
#   'FES2022',
#   'FES2022_extrapolated',
#   'FES2022_load',
#   'GOT4.10',
#   'GOT4.10_load',
#   'GOT4.7',
#   'GOT4.7_load',
#   'GOT4.8',
#   'GOT4.8_load',
#   'GOT5.5',
#   'GOT5.5D',
#   'GOT5.5D_extrapolated',
#   'GOT5.5_extrapolated',
#   'GOT5.5_load',
#   'GOT5.6',
#   'GOT5.6_extrapolated',
#   'Gr1km-v2',
#   'Gr1kmTM',
#   'HAMTIDE11',
#   'INATIDES',
#   'RE14',
#   'TPXO10-atlas-v2',
#   'TPXO10-atlas-v2-nc',
#   'TPXO7.2',
#   'TPXO7.2_load',
#   'TPXO8-atlas',
#   'TPXO8-atlas-nc',
#   'TPXO9-atlas',
#   'TPXO9-atlas-nc',
#   'TPXO9-atlas-v2',
#   'TPXO9-atlas-v2-nc',
#   'TPXO9-atlas-v3',
#   'TPXO9-atlas-v3-nc',
#   'TPXO9-atlas-v4',
#   'TPXO9-atlas-v4-nc',
#   'TPXO9-atlas-v5',
#   'TPXO9-atlas-v5-nc',
#   'TPXO9.1'])

# %%
dc = datacube.Datacube(app='Coastal_erosion')

# %%
lat_range = (-8.3463, -8.31713)
lon_range = (115.62202, 115.67076)
time_range = ('2017', '2024')
time_step = '1Y'

# %%
display_map(x=lon_range, y=lat_range)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86009f5b505be355f814a2012f25482b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86009f5b505be355f814a2012f25482b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86009f5b505be355f814a2012f25482b = L.map(
#                 &quot;map_86009f5b505be355f814a2012f25482b&quot;,
#                 {
#                     center: [-8.331714999999999, 115.64639],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23fe1d15ea0ce0a1324dac61505093d3 = L.tileLayer(
#                 &quot;http://mt1.google.com/vt/lyrs=y\u0026z={z}\u0026x={x}\u0026y={y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23fe1d15ea0ce0a1324dac61505093d3.addTo(map_86009f5b505be355f814a2012f25482b);
#
#
#             var poly_line_aec5f9ba105673d4a9498dc1aa043be1 = L.polyline(
#                 [[-8.3463, 115.62202], [-8.3463, 115.67076], [-8.31713, 115.67076], [-8.31713, 115.62202], [-8.3463, 115.62202]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86009f5b505be355f814a2012f25482b);
#
#
#                 var lat_lng_popup_d5df8f68ba00e52d21740cdf5be5855a = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_d5df8f68ba00e52d21740cdf5be5855a
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_86009f5b505be355f814a2012f25482b);
#                     }
#                 map_86009f5b505be355f814a2012f25482b.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create the 'query' dictionary object, which contains the longitudes, 
# latitudes and time provided above
query = {
    'y': lat_range,
    'x': lon_range,
    'time': time_range,
    'measurements': ['blue', 'green', 'red', 'swir_1'],
    'resolution': (-20, 20),
}

# Identify the most common projection system in the input query 
output_crs = mostcommon_crs(dc=dc, product='s2_l2a', query=query)

# Load available data from Sentinel-2 satellites
sentinel_ds = load_ard(
    dc=dc,
    products=[
        's2_l2a'
    ],
    output_crs=output_crs,
    group_by='solar_day',
    dask_chunks={},
    **query
)
# Out:
# Querying product Product(name='s2_l2a', id_=9)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 15
#      12 output_crs = mostcommon_crs(dc=dc, product='s2_l2a', query=query)
#      14 # Load available data from Sentinel-2 satellites
# ---> 15 sentinel_ds = load(
#      16     dc=dc,
#      17     products=[
#      18         's2_l2a'
#      19     ],
#      20     output_crs=output_crs,
#      21     group_by='solar_day',
#      22     dask_chunks={},
#      23     **query
#      24 )
#
# NameError: name 'load' is not defined
